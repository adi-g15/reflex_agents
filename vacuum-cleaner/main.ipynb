# %%
import import_ipynb
from time import sleep
from cleaner import VacuumCleaner, simple_reflex_agent
# Out:
# importing Jupyter notebook from cleaner.ipynb
# importing Jupyter notebook from sensors.ipynb
# importing Jupyter notebook from environment.ipynb
# Sofa

# %%
## Q1 Using a simple reflex agent

# Create vacuum cleaner
cleaner = VacuumCleaner()
while True:
    cleaner.attempt_clean(agent=simple_reflex_agent())
    print("Current performance: ", cleaner.perf)  # for now, it ALWAYS increases
    sleep(1.5)
# Out:
# Initial State:
#
# *     *   *
#     * *   *
# * *   *
# * *   * * *
#     *     *
# Moving Down
# Cleaning:  [4, 3]
#
# *     *   *
#     * *   *
# * *   *
# * *     * *
#     *     *
# Current performance:  2.44
# Moving Down
# Cleaning:  [4, 4]
#
# *     *   *
#     * *   *
# * *   *
# * *       *
#     *     *
# Current performance:  4.84
# Moving Up
# Cleaning:  [2, 3]
#
# *     *   *
#     *     *
# * *   *
# * *       *
#     *     *
# Current performance:  7.12
# Moving Left
# Cleaning:  [1, 5]
#
# *     *
#     *     *
# * *   *
# * *       *
#     *     *
# Current performance:  9.440000000000001
# Moving
# Cleaning:  [1, 3]
#
# *
#     *     *
# * *   *
# * *       *
#     *     *
# Current performance:  11.56
# Moving
# Cleaning:  [3, 1]
#
# *
#     *     *
# *     *
# * *       *
#     *     *
# Current performance:  13.72
# Moving Up
# Cleaning:  [3, 0]
#
# *
#     *     *
#       *
# * *       *
#     *     *
# Current performance:  16.0
# Moving Right
# Cleaning:  [4, 0]
#
# *
#     *     *
#       *
#   *       *
#     *     *
# Current performance:  18.2
# Moving Down
# Cleaning:  [4, 1]
#
# *
#     *     *
#       *
#           *
#     *     *
# Current performance:  20.32
# Moving Right Down
# Cleaning:  [5, 2]
#
# *
#     *     *
#       *
#           *
#           *
# Current performance:  22.44
# Moving Down
# Cleaning:  [3, 3]
#
# *
#     *     *
#
#           *
#           *
# Current performance:  24.48
# Moving Left Up
# Cleaning:  [2, 2]
#
# *
#           *
#
#           *
#           *
# Current performance:  26.64
# Moving Left
# Cleaning:  [1, 0]
#
#
#           *
#
#           *
#           *
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# ...
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68
# No dirt found by sensor (ie. in 2 unit distance)
# Not Moving
# Already clean:  [1, 0]
# Current performance:  28.68

# %% [markdown]
# #### We can see here, it failed to clean the corner, since it was at another corner AND THE SENSOR CAN'T TELL THE ENVIRONMENT farther than 2 unit distance
